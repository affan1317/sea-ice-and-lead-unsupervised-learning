# %% [markdown]
# <a href="https://colab.research.google.com/github/affan1317/sea-ice-and-lead-unsupervised-learning/blob/main/Chapter1_Unsupervised_Learning_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unsupervised Learning
#
# This section marks our journey into another significant domain of machine learning and AI: unsupervised learning. Rather than delving deep into theoretical intricacies, our focus here will be on offering a practical guide. We aim to equip you with a clear understanding and effective tools for employing unsupervised learning methods in real-world (EO) scenarios.
#
# It's important to note that, while unsupervised learning encompasses a broad range of applications, our discussion will predominantly revolve around classification tasks. This is because unsupervised learning techniques are exceptionally adept at identifying patterns and categorising data when the classifications are not explicitly labeled. By exploring these techniques, you'll gain insights into how to discern structure and relationships within your datasets, even in the absence of predefined categories or labels.
#
# The tasks in this notebook will be mainly two:
# 1. Discrimination of Sea ice and lead based on image classification based on Sentinel-2 optical data.
# 2. Discrimination of Sea ice and lead based on altimetry data classification based on Sentinel-3 altimetry data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Introduction to Unsupervised Learning Methods {cite}`bishop2006pattern`
#
# ### Introduction to K-means Clustering
#
# K-means clustering is a type of unsupervised learning algorithm used for partitioning a dataset into a set of k groups (or clusters), where k represents the number of groups pre-specified by the analyst. It classifies the data points based on the similarity of the features of the data {cite}`macqueen1967some`. The basic idea is to define k centroids, one for each cluster, and then assign each data point to the nearest centroid, while keeping the centroids as small as possible.
#
# ### Why K-means for Clustering?
#
# K-means clustering is particularly well-suited for applications where:
#
# - **The structure of the data is not known beforehand**: K-means doesn’t require any prior knowledge about the data distribution or structure, making it ideal for exploratory data analysis.
# - **Simplicity and scalability**: The algorithm is straightforward to implement and can scale to large datasets relatively easily.
#
# ### Key Components of K-means
#
# 1. **Choosing K**: The number of clusters (k) is a parameter that needs to be specified before applying the algorithm.
# 2. **Centroids Initialization**: The initial placement of the centroids can affect the final results.
# 3. **Assignment Step**: Each data point is assigned to its nearest centroid, based on the squared Euclidean distance.
# 4. **Update Step**: The centroids are recomputed as the center of all the data points assigned to the respective cluster.
#
# ### The Iterative Process of K-means
#
# The assignment and update steps are repeated iteratively until the centroids no longer move significantly, meaning the within-cluster variation is minimised. This iterative process ensures that the algorithm converges to a result, which might be a local optimum.
#
# ### Advantages of K-means
#
# - **Efficiency**: K-means is computationally efficient.
# - **Ease of interpretation**: The results of k-means clustering are easy to understand and interpret.
#
# ### Basic Code Implementation
#
# Below, you'll find a basic implementation of the K-means clustering algorithm. This serves as a foundational understanding and a starting point for applying the algorithm to your specific data analysis tasks.

# %%
# Python code for K-means clustering
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# Sample data
X = np.random.rand(100, 2)

# K-means model
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# Plotting
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ## Gaussian Mixture Models (GMM) {cite}`bishop2006pattern`
#
# ### Introduction to Gaussian Mixture Models
#
# Gaussian Mixture Models (GMM) are a probabilistic model for representing normally distributed subpopulations within an overall population. The model assumes that the data is generated from a mixture of several Gaussian distributions, each with its own mean and variance {cite}`reynolds2009gaussian, mclachlan2004finite`. GMMs are widely used for clustering and density estimation, as they provide a method for representing complex distributions through the combination of simpler ones.
#
# ### Why Gaussian Mixture Models for Clustering?
#
# Gaussian Mixture Models are particularly powerful in scenarios where:
#
# - **Soft clustering is needed**: Unlike K-means, GMM provides the probability of each data point belonging to each cluster, offering a soft classification and understanding of the uncertainties in our data.
# - **Flexibility in cluster covariance**: GMM allows for clusters to have different sizes and different shapes, making it more flexible to capture the true variance in the data.
#
# ### Key Components of GMM
#
# 1. **Number of Components (Gaussians)**: Similar to K in K-means, the number of Gaussians (components) is a parameter that needs to be set.
# 2. **Expectation-Maximization (EM) Algorithm**: GMMs use the EM algorithm for fitting, iteratively improving the likelihood of the data given the model.
# 3. **Covariance Type**: The shape, size, and orientation of the clusters are determined by the covariance type of the Gaussians (e.g., spherical, diagonal, tied, or full covariance).
#
# ### The EM Algorithm in GMM
#
# The Expectation-Maximization (EM) algorithm is a two-step process:
#
# - **Expectation Step (E-step)**: Calculate the probability that each data point belongs to each cluster.
# - **Maximization Step (M-step)**: Update the parameters of the Gaussians (mean, covariance, and mixing coefficient) to maximize the likelihood of the data given these assignments.
#
# This process is repeated until convergence, meaning the parameters do not significantly change from one iteration to the next.
#
# ### Advantages of GMM
#
# - **Soft Clustering**: Provides a probabilistic framework for soft clustering, giving more information about the uncertainties in the data assignments.
# - **Cluster Shape Flexibility**: Can adapt to ellipsoidal cluster shapes, thanks to the flexible covariance structure.
#
# ### Basic Code Implementation
#
# Below, you'll find a basic implementation of the Gaussian Mixture Model. This should serve as an initial guide for understanding the model and applying it to your data analysis projects.

# %%
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt
import numpy as np

# Sample data
X = np.random.rand(100, 2)

# GMM model
gmm = GaussianMixture(n_components=3)
gmm.fit(X)
y_gmm = gmm.predict(X)

# Plotting
plt.scatter(X[:, 0], X[:, 1], c=y_gmm, cmap='viridis')
centers = gmm.means_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
plt.title('Gaussian Mixture Model')
plt.show()

# %% [markdown]
# ### Support Vector Machine

# %% [markdown]
# ## Image Classification
# Now, let's explore the application of these unsupervised methods to image classification tasks, focusing specifically on distinguishing between sea ice and leads in Sentinel-2 imagery.
#
# ### K-Means Implementation

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (1.3.9)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2023.11.17)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.23.5)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.1)

# %%
import rasterio
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

base_path = "/content/drive/MyDrive/GEOL0069/Week_4/S2A_MSIL1C_20190301T235611_N0207_R116_T01WCU_20190302T014622.SAFE/GRANULE/L1C_T01WCU_A019275_20190301T235610/IMG_DATA/" # You need to specify the path
bands_paths = {
    'B4': base_path + 'T01WCU_20190301T235611_B04.jp2',
    'B3': base_path + 'T01WCU_20190301T235611_B03.jp2',
    'B2': base_path + 'T01WCU_20190301T235611_B02.jp2'
}

# Read and stack the band images
band_data = []
for band in ['B4', 'B3', 'B2']:
    with rasterio.open(bands_paths[band]) as src:
        band_data.append(src.read(1))

# Stack bands and create a mask for valid data (non-zero values in all bands)
band_stack = np.dstack(band_data)
valid_data_mask = np.all(band_stack > 0, axis=2)

# Reshape for K-means, only including valid data
X = band_stack[valid_data_mask].reshape((-1, 3))

# K-means clustering
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
labels = kmeans.labels_

# Create an empty array for the result, filled with a no-data value (e.g., -1)
labels_image = np.full(band_stack.shape[:2], -1, dtype=int)

# Place cluster labels in the locations corresponding to valid data
labels_image[valid_data_mask] = labels

# Plotting the result
plt.imshow(labels_image, cmap='viridis')
plt.title('K-means clustering on Sentinel-2 Bands')
plt.colorbar(label='Cluster Label')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
band_stack.shape
# Out:
# (10980, 10980, 3)

# %%
plt.hist(band_stack[::100,::100,0].ravel(), bins=100, range=(2000,10000), label='blue')
plt.hist(band_stack[::100,::100,1].ravel(), bins=100, range=(2000,10000), label='red')
plt.hist(band_stack[::100,::100,2].ravel(), bins=100, range=(2000,10000), label='green')
plt.legend()

# %% [markdown]
# ### GMM Implementation

# %%
import rasterio
import numpy as np
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt

# Paths to the band images
base_path = "/content/drive/MyDrive/GEOL0069/Week_4/S2A_MSIL1C_20190301T235611_N0207_R116_T01WCU_20190302T014622.SAFE/GRANULE/L1C_T01WCU_A019275_20190301T235610/IMG_DATA/"
bands_paths = {
    'B4': base_path + 'T01WCU_20190301T235611_B04.jp2',
    'B3': base_path + 'T01WCU_20190301T235611_B03.jp2',
    'B2': base_path + 'T01WCU_20190301T235611_B02.jp2'
}

# Read and stack the band images
band_data = []
for band in ['B4', 'B3', 'B2']:
    with rasterio.open(bands_paths[band]) as src:
        band_data.append(src.read(1))

# Stack bands and create a mask for valid data (non-zero values in all bands)
band_stack = np.dstack(band_data)
valid_data_mask = np.all(band_stack > 0, axis=2)

# Reshape for GMM, only including valid data
X = band_stack[valid_data_mask].reshape((-1, 3))

# GMM clustering
gmm = GaussianMixture(n_components=2, random_state=0).fit(X)
labels = gmm.predict(X)

# Create an empty array for the result, filled with a no-data value (e.g., -1)
labels_image = np.full(band_stack.shape[:2], -1, dtype=int)

# Place GMM labels in the locations corresponding to valid data
labels_image[valid_data_mask] = labels

# Plotting the result
plt.imshow(labels_image, cmap='viridis')
plt.title('GMM clustering on Sentinel-2 Bands')
plt.colorbar(label='Cluster Label')
plt.show()

# %% [markdown]
# ## Altimetry Classification
# Now, let's explore the application of these unsupervised methods to altimetry classification tasks, focusing specifically on distinguishing between sea ice and leads in Sentinel-3 altimetry dataset.

# %% [markdown]
# ### Read in Functions Needed
# Before delving into the modeling process, it's crucial to preprocess the data to ensure compatibility with our analytical models. This involves transforming the raw data into meaningful variables, such as peakniness and stack standard deviation (SSD), etc.

# %%
#!pip install netCDF4
#!pip install basemap
#!pip install cartopy

from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import numpy.ma as ma
import glob
from matplotlib.patches import Polygon
import scipy.spatial as spatial
from scipy.spatial import KDTree

import pyproj
import cartopy.crs as ccrs
from sklearn.cluster import KMeans, DBSCAN
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.mixture import GaussianMixture
from scipy.cluster.hierarchy import linkage, fcluster

#=========================================================================================================
#===================================  SUBFUNCTIONS  ======================================================
#=========================================================================================================

#*args and **kwargs allow you to pass an unspecified number of arguments to a function,
#so when writing the function definition, you do not need to know how many arguments will be passed to your function
#**kwargs allows you to pass keyworded variable length of arguments to a function.
#You should use **kwargs if you want to handle named arguments in a function.
#double star allows us to pass through keyword arguments (and any number of them).
def peakiness(waves, **kwargs):

    "finds peakiness of waveforms."

    #print("Beginning peakiness")
    # Kwargs are:
    #          wf_plots. specify a number n: wf_plots=n, to show the first n waveform plots. \

    import numpy as np
    import matplotlib
    import matplotlib.pyplot as plt
    import time

    print("Running peakiness function...")

    size=np.shape(waves)[0] #.shape property is a tuple of length .ndim containing the length of each dimensions
                            #Tuple of array dimensions.

    waves1=np.copy(waves)

    if waves1.ndim == 1: #number of array dimensions
        print('only one waveform in file')
        waves2=waves1.reshape(1,np.size(waves1)) #numpy.reshape(a, newshape, order='C'), a=array to be reshaped
        waves1=waves2

    # *args is used to send a non-keyworded variable length argument list to the function
    def by_row(waves, *args):
        "calculate peakiness for each waveform"
        maximum=np.nanmax(waves)
        if maximum > 0:

            maximum_bin=np.where(waves==maximum)
            #print(maximum_bin)
            maximum_bin=maximum_bin[0][0]
            waves_128=waves[maximum_bin-50:maximum_bin+78]

            waves=waves_128

            noise_floor=np.nanmean(waves[10:20])
            where_above_nf=np.where(waves > noise_floor)

            if np.shape(where_above_nf)[1] > 0:
                maximum=np.nanmax(waves[where_above_nf])
                total=np.sum(waves[where_above_nf])
                mean=np.nanmean(waves[where_above_nf])
                peaky=maximum/mean

            else:
                peaky = np.nan
                maximum = np.nan
                total = np.nan

        else:
            peaky = np.nan
            maximum = np.nan
            total = np.nan

        if 'maxs' in args:
            return maximum
        if 'totals' in args:
            return total
        if 'peaky' in args:
            return peaky

    peaky=np.apply_along_axis(by_row, 1, waves1, 'peaky') #numpy.apply_along_axis(func1d, axis, arr, *args, **kwargs)

    if 'wf_plots' in kwargs:
        maximums=np.apply_along_axis(by_row, 1, waves1, 'maxs')
        totals=np.apply_along_axis(by_row, 1, waves1, 'totals')

        for i in range(0,kwargs['wf_plots']):
            if i == 0:
                print("Plotting first "+str(kwargs['wf_plots'])+" waveforms")

            plt.plot(waves1[i,:])#, a, col[i],label=label[i])
            plt.axhline(maximums[i], color='green')
            plt.axvline(10, color='r')
            plt.axvline(19, color='r')
            plt.xlabel('Bin (of 256)')
            plt.ylabel('Power')
            plt.text(5,maximums[i],"maximum="+str(maximums[i]))
            plt.text(5,maximums[i]-2500,"total="+str(totals[i]))
            plt.text(5,maximums[i]-5000,"peakiness="+str(peaky[i]))
            plt.title('waveform '+str(i)+' of '+str(size)+'\n. Noise floor average taken between red lines.')
            plt.show()


    return peaky

#=========================================================================================================
#=========================================================================================================
#=========================================================================================================


def unpack_gpod(variable):

    from scipy.interpolate import interp1d

    time_1hz=SAR_data.variables['time_01'][:]
    time_20hz=SAR_data.variables['time_20_ku'][:]
    time_20hzC = SAR_data.variables['time_20_c'][:]

    out=(SAR_data.variables[variable][:]).astype(float)  # convert from integer array to float.

    #if ma.is_masked(dataset.variables[variable][:]) == True:
    #print(variable,'is masked. Removing mask and replacing masked values with nan')
    out=np.ma.filled(out, np.nan)

    if len(out)==len(time_1hz):

        print(variable,'is 1hz. Expanding to 20hz...')
        out = interp1d(time_1hz,out,fill_value="extrapolate")(time_20hz)

    if len(out)==len(time_20hzC):
        print(variable, 'is c band, expanding to 20hz ku band dimension')
        out = interp1d(time_20hzC,out,fill_value="extrapolate")(time_20hz)
    return out


#=========================================================================================================
#=========================================================================================================
#=========================================================================================================

def calculate_SSD(RIP):

    from scipy.optimize import curve_fit
    from scipy import asarray as ar,exp
    do_plot='Off'

    def gaussian(x,a,x0,sigma):
            return a * np.exp(-(x - x0)**2 / (2 * sigma**2))

    SSD=np.zeros(np.shape(RIP)[0])*np.nan
    x=np.arange(np.shape(RIP)[1])

    for i in range(np.shape(RIP)[0]):

        y=np.copy(RIP[i])
        y[(np.isnan(y)==True)]=0

        if 'popt' in locals():
            del(popt,pcov)

        SSD_calc=0.5*(np.sum(y**2)*np.sum(y**2)/np.sum(y**4))
        #print('SSD calculated from equation',SSD)

        #n = len(x)
        mean_est = sum(x * y) / sum(y)
        sigma_est = np.sqrt(sum(y * (x - mean_est)**2) / sum(y))
        #print('est. mean',mean,'est. sigma',sigma_est)

        try:
            popt,pcov = curve_fit(gaussian, x, y, p0=[max(y), mean_est, sigma_est],maxfev=10000)
        except RuntimeError as e:
            print("Gaussian SSD curve-fit error: "+str(e))
            #plt.plot(y)
            #plt.show()

        except TypeError as t:
            print("Gaussian SSD curve-fit error: "+str(t))

        if do_plot=='ON':

            plt.plot(x,y)
            plt.plot(x,gaussian(x,*popt),'ro:',label='fit')
            plt.axvline(popt[1])
            plt.axvspan(popt[1]-popt[2], popt[1]+popt[2], alpha=0.15, color='Navy')
            plt.show()

            print('popt',popt)
            print('curve fit SSD',popt[2])

        if 'popt' in locals():
            SSD[i]=abs(popt[2])


    return SSD
# Out:
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.10/dist-packages (1.6.5)
# Requirement already satisfied: cftime in /usr/local/lib/python3.10/dist-packages (from netCDF4) (1.6.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netCDF4) (2023.11.17)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from netCDF4) (1.23.5)
# Requirement already satisfied: basemap in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Requirement already satisfied: basemap-data<1.4,>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from basemap) (1.3.2)
# Requirement already satisfied: pyshp<2.4,>=1.2 in /usr/local/lib/python3.10/dist-packages (from basemap) (2.3.1)
# Requirement already satisfied: matplotlib<3.9,>=1.5 in /usr/local/lib/python3.10/dist-packages (from basemap) (3.7.1)
# Requirement already satisfied: pyproj<3.7.0,>=1.9.3 in /usr/local/lib/python3.10/dist-packages (from basemap) (3.6.1)
# Requirement already satisfied: packaging<24.0,>=16.0 in /usr/local/lib/python3.10/dist-packages (from basemap) (23.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in /usr/local/lib/python3.10/dist-packages (from basemap) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj<3.7.0,>=1.9.3->basemap) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.9,>=1.5->basemap) (1.16.0)
# Requirement already satisfied: cartopy in /usr/local/lib/python3.10/dist-packages (0.22.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from cartopy) (1.23.5)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.7.1)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.1 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.1.0->cartopy) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)

# %%
path = '/content/drive/MyDrive/GEOL0069/Week_4/'
SAR_file='S3B_SR_2_LAN_SI_20190301T231304_20190301T233006_20230405T162425_1021_022_301______LN3_R_NT_005'
print('overlapping SAR file is',SAR_file)
SAR_data = Dataset('/content/drive/MyDrive/GEOL0069/Week_4/'+ SAR_file + '/enhanced_measurement.nc')

SAR_lat, SAR_lon, waves, sig_0, RIP= unpack_gpod('lat_20_ku'), unpack_gpod('lon_20_ku'), unpack_gpod('waveform_20_ku'),unpack_gpod('sig0_water_20_ku'),unpack_gpod('rip_20_ku')#unpack_gpod('Sigma0_20Hz')
SAR_index=np.arange(np.size(SAR_lat))

find=np.where(SAR_lat >= -99999)#60
SAR_lat=SAR_lat[find]
SAR_lon=SAR_lon[find]
SAR_index=SAR_index[find]
waves=waves[find]
sig_0=sig_0[find]
RIP=RIP[find]

PP=peakiness(waves)
SSD=calculate_SSD(RIP)
sig_0_np = np.array(sig_0)  # Replace [...] with your data
RIP_np = np.array(RIP)
PP_np = np.array(PP)
SSD_np = np.array(SSD)

data = np.column_stack((sig_0_np,PP_np, SSD_np))
# Standardize the data
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data)
# Out:
# overlapping SAR file is S3B_SR_2_LAN_SI_20190301T231304_20190301T233006_20230405T162425_1021_022_301______LN3_R_NT_005
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-d271726355dd> in <cell line: 4>()
#       2 SAR_file='S3B_SR_2_LAN_SI_20190301T231304_20190301T233006_20230405T162425_1021_022_301______LN3_R_NT_005'
#       3 print('overlapping SAR file is',SAR_file)
# ----> 4 SAR_data = Dataset('/content/drive/MyDrive/GEOL0069/Week_4/'+ SAR_file + '/enhanced_measurement.nc')
#       5
#       6 SAR_lat, SAR_lon, waves, sig_0, RIP= unpack_gpod('lat_20_ku'), unpack_gpod('lon_20_ku'), unpack_gpod('waveform_20_ku'),unpack_gpod('sig0_water_20_ku'),unpack_gpod('rip_20_ku')#unpack_gpod('Sigma0_20Hz')
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/GEOL0069/Week_4/S3B_SR_2_LAN_SI_20190301T231304_20190301T233006_20230405T162425_1021_022_301______LN3_R_NT_005/enhanced_measurement.nc'

# %%
SAR_data.variables
# Out:
# {'time_01': <class 'netCDF4._netCDF4.Variable'>
#  float64 time_01(time_01)
#      long_name: UTC: 1 Hz
#      units: seconds since 2000-01-01 00:00:00.0
#      standard_name: time
#      calendar: gregorian
#  unlimited dimensions:
#  current shape = (661,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'time_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  float64 time_20_ku(time_20_ku)
#      long_name: UTC: 20 Hz Ku band
#      units: seconds since 2000-01-01 00:00:00.0
#      standard_name: time
#      calendar: gregorian
#      comment: Datation of SAR mode measurements (or LRM measurements acquired during early commissioning phase)
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'time_20_c': <class 'netCDF4._netCDF4.Variable'>
#  float64 time_20_c(time_20_c)
#      long_name: UTC: 20 Hz C band
#      units: seconds since 2000-01-01 00:00:00.0
#      standard_name: time
#      calendar: gregorian
#      comment: Datation of C-band and Pseudo-LRM measurements
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'echo_sample_ind': <class 'netCDF4._netCDF4.Variable'>
#  int8 echo_sample_ind(echo_sample_ind)
#      long_name: number of samples in the waveforms
#      units: count
#      comment: Set to be compliant with the CF-1.1 convention
#  unlimited dimensions:
#  current shape = (128,)
#  filling on, default _FillValue of -127 ignored,
#  'wf_sample_ind': <class 'netCDF4._netCDF4.Variable'>
#  int16 wf_sample_ind(wf_sample_ind)
#      long_name: number of samples in I2+Q2 waveforms
#      units: count
#      comment: Set to be compliant with the CF-1.6 convention
#  unlimited dimensions:
#  current shape = (256,)
#  filling on, default _FillValue of -32767 used,
#  'max_multi_stack_ind': <class 'netCDF4._netCDF4.Variable'>
#  int16 max_multi_stack_ind(max_multi_stack_ind)
#      long_name: maximum number of multilook beams per stack
#      units: count
#      comment: Set to be compliant with the CF-1.6 convention
#  unlimited dimensions:
#  current shape = (256,)
#  filling on, default _FillValue of -32767 used,
#  'UTC_day_01': <class 'netCDF4._netCDF4.Variable'>
#  int16 UTC_day_01(time_01)
#      long_name: day UTC : 1 Hz
#      units: days since 2000-01-01 00:00:00.0
#  unlimited dimensions:
#  current shape = (661,)
#  filling on, default _FillValue of -32767 used,
#  'UTC_sec_01': <class 'netCDF4._netCDF4.Variable'>
#  float64 UTC_sec_01(time_01)
#      long_name: Second in the day UTC : 1 Hz
#      units: s
#  unlimited dimensions:
#  current shape = (661,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'UTC_day_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 UTC_day_20_ku(time_20_ku)
#      long_name: day UTC : 20 Hz Ku band
#      units: days since 2000-01-01 00:00:00.0
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on, default _FillValue of -32767 used,
#  'UTC_sec_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  float64 UTC_sec_20_ku(time_20_ku)
#      long_name: Second in the day UTC : 20 Hz Ku band
#      units: s
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'UTC_day_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 UTC_day_20_c(time_20_c)
#      long_name: day UTC : 20 Hz C band
#      units: days since 2000-01-01 00:00:00.0
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on, default _FillValue of -32767 used,
#  'UTC_sec_20_c': <class 'netCDF4._netCDF4.Variable'>
#  float64 UTC_sec_20_c(time_20_c)
#      long_name: Second in the day UTC : 20 Hz C band
#      units: s
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'UTC_time_1hz_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  float64 UTC_time_1hz_20_ku(time_20_ku)
#      long_name: UTC of the 1 Hz measurement
#      units: seconds since 2000-01-01 00:00:00.0
#      calendar: gregorian
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'UTC_time_1hz_20_c': <class 'netCDF4._netCDF4.Variable'>
#  float64 UTC_time_1hz_20_c(time_20_c)
#      long_name: UTC of the 1 Hz measurement
#      units: seconds since 2000-01-01 00:00:00.0
#      calendar: gregorian
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'lat_01': <class 'netCDF4._netCDF4.Variable'>
#  int32 lat_01(time_01)
#      long_name: latitude : 1 Hz
#      units: degrees_north
#      standard_name: latitude
#      add_offset: 0.0
#      scale_factor: 1e-06
#      comment: Positive latitude is North latitude, negative latitude is South latitude
#  unlimited dimensions:
#  current shape = (661,)
#  filling on, default _FillValue of -2147483647 used,
#  'lon_01': <class 'netCDF4._netCDF4.Variable'>
#  int32 lon_01(time_01)
#      long_name: longitude : 1 Hz
#      units: degrees_east
#      standard_name: longitude
#      add_offset: 0.0
#      scale_factor: 1e-06
#      comment: East longitude relative to Greenwich meridian
#  unlimited dimensions:
#  current shape = (661,)
#  filling on, default _FillValue of -2147483647 used,
#  'lat_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 lat_20_ku(time_20_ku)
#      long_name: latitude : 20 Hz Ku band
#      units: degrees_north
#      standard_name: latitude
#      add_offset: 0.0
#      scale_factor: 1e-06
#      comment: Latitude of SAR mode measurements (or LRM measurements acquired during early commissioning phase). Positive latitude is North latitude, negative latitude is South latitude"
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on, default _FillValue of -2147483647 used,
#  'lon_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 lon_20_ku(time_20_ku)
#      long_name: longitude : 20 Hz Ku band
#      units: degrees_east
#      standard_name: longitude
#      add_offset: 0.0
#      scale_factor: 1e-06
#      comment: Longitude of SAR mode measurements (or LRM measurements acquired during early commissioning phase) [0,+360]. East longitude relative to Greenwich meridian
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on, default _FillValue of -2147483647 used,
#  'lat_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int32 lat_20_c(time_20_c)
#      long_name: latitude : 20 Hz C band
#      units: degrees_north
#      standard_name: latitude
#      add_offset: 0.0
#      scale_factor: 1e-06
#      comment: Latitude of C-band and Pseudo-LRM measurements. Positive latitude is North latitude, negative latitude is South latitude
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on, default _FillValue of -2147483647 used,
#  'lon_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int32 lon_20_c(time_20_c)
#      long_name: longitude : 20 Hz C band
#      units: degrees_east
#      standard_name: longitude
#      add_offset: 0.0
#      scale_factor: 1e-06
#      comment: Longitude of C-band and Pseudo-LRM measurements [0,+360]. East longitude relative to Greenwich meridian
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on, default _FillValue of -2147483647 used,
#  'surf_type_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 surf_type_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: surface type : 20 Hz Ku band
#      flag_values: [0 1 2 3]
#      flag_meanings: ocean_or_semi_enclosed_sea enclosed_sea_or_lake continental_ice land
#      coordinates: lon_20_ku lat_20_ku
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'surf_type_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 surf_type_20_c(time_20_c)
#      _FillValue: 127
#      long_name: surface type : 20 Hz C band
#      flag_values: [0 1 2 3]
#      flag_meanings: ocean_or_semi_enclosed_sea enclosed_sea_or_lake continental_ice land
#      coordinates: lon_20_c lat_20_c
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'surf_class_01': <class 'netCDF4._netCDF4.Variable'>
#  int8 surf_class_01(time_01)
#      long_name: surface classification : 01 Hz
#      flag_values: [0 1 2 3 4 5 6]
#      flag_meanings: open_ocean land continental_water aquatic_vegetation continental_ice_snow floating_ice salted_basin
#      coordinates: lon_01 lat_01
#      _FillValue: 127
#      comment: A 7-states surface type mask for the surface type at the nadir location. Computed at CLS by combining data from MODIS and GlobCover
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'surf_class_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 surf_class_20_ku(time_20_ku)
#      long_name: surface classification : 20 Hz ku band
#      flag_values: [0 1 2 3 4 5 6]
#      flag_meanings: open_ocean land continental_water aquatic_vegetation continental_ice_snow floating_ice salted_basin
#      coordinates: lon_20_ku lat_20_ku
#      _FillValue: 127
#      comment: A 7-states surface type mask for the surface type at the nadir location. Computed at CLS by combining data from MODIS and GlobCover
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'surf_class_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 surf_class_20_c(time_20_c)
#      long_name: surface classification : 20 Hz C band
#      flag_values: [0 1 2 3 4 5 6]
#      flag_meanings: open_ocean land continental_water aquatic_vegetation continental_ice_snow floating_ice salted_basin
#      coordinates: lon_20_c lat_20_c
#      _FillValue: 127
#      comment: A 7-states surface type mask for the surface type at the nadir location. Computed at CLS by combining data from MODIS and GlobCover
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'rad_surf_type_01': <class 'netCDF4._netCDF4.Variable'>
#  int8 rad_surf_type_01(time_01)
#      _FillValue: 127
#      long_name: radiometer derived surface type : 1 Hz
#      flag_values: [0 1]
#      flag_meanings: ocean land
#      coordinates: lon_01 lat_01
#      comment: References: Ruf, C.S., 1999a : Jason Microwave Radiometer – Land Contamination of Path Delay Retrieval. 22 February 1999
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'angle_coast_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 angle_coast_20_ku(time_20_ku)
#      _FillValue: 32767
#      long_name: angle to the coast : 20 Hz Ku band
#      units: degree
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_ku lat_20_ku
#      comment: Angle to the coast extracted from the Global Self-consistent, Hierarchical, High-resolution Geography Database (GSHHG v2.3.7). 0 is parallel to the coast with the land on the right. Positive values indicate the satellite is approaching the land. Negative values indicate the satellite is leaving the land
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'dist_coast_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 dist_coast_20_ku(time_20_ku)
#      _FillValue: 2147483647
#      long_name: distance to the coast : 20 Hz Ku band
#      units: m
#      coordinates: lon_20_ku lat_20_ku
#      comment: Distance to the coast extracted from the Global Self-consistent, Hierarchical, High-resolution Geography Database (GSHHG v2.3.7)
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'alt_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 alt_20_ku(time_20_ku)
#      _FillValue: 2147483647
#      long_name: altitude of the satellite : 20 Hz Ku band
#      units: m
#      standard_name: height_above_reference_ellipsoid
#      add_offset: 700000.0
#      scale_factor: 0.0001
#      coordinates: lon_20_ku lat_20_ku
#      comment: Altitude of satellite above the reference ellipsoid (WGS 84)
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'alt_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int32 alt_20_c(time_20_c)
#      _FillValue: 2147483647
#      long_name: altitude of the satellite : 20 Hz C band
#      units: m
#      standard_name: height_above_reference_ellipsoid
#      add_offset: 700000.0
#      scale_factor: 0.0001
#      coordinates: lon_20_c lat_20_c
#      comment: Altitude of satellite above the reference ellipsoid (WGS 84)
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'orb_alt_rate_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 orb_alt_rate_20_ku(time_20_ku)
#      _FillValue: 32767
#      long_name: orbital altitude rate : 20 Hz Ku band
#      units: m/s
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_ku lat_20_ku
#      comment: The reference surface for the orbital altitude rate is the combined mean_sea_surface/geoid surface. It is used to compute the Doppler correction on the altimeter range
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'orb_alt_rate_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 orb_alt_rate_20_c(time_20_c)
#      _FillValue: 32767
#      long_name: orbital altitude rate : 20 Hz C band
#      units: m/s
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_c lat_20_c
#      comment: The reference surface for the orbital altitude rate is the combined mean_sea_surface/geoid surface. It is used to compute the Doppler correction on the altimeter range
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'tracker_range_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 tracker_range_20_ku(time_20_ku)
#      _FillValue: 2147483647
#      long_name: corrected tracker range for : 20 Hz Ku band
#      units: m
#      add_offset: 700000.0
#      scale_factor: 0.0001
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: tracker range corrected for USO frequency drift (uso_cor_20_ku), internal path delay (int_path_cor_20_ku) and antenna-COG distance (cog_cor_01). For measurements acquired in LRM during early commissioning phase, the Doppler correction is added (dop_cor_l1b_20_ku)
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'tracker_range_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int32 tracker_range_20_c(time_20_c)
#      _FillValue: 2147483647
#      long_name: corrected tracker range for : 20 Hz C band
#      units: m
#      add_offset: 700000.0
#      scale_factor: 0.0001
#      coordinates: lon_20_c lat_20_c
#      comment: C band: tracker range corrected for USO frequency drift (uso_cor_20_c), internal path delay (int_path_cor_20_c), Doppler effect (dop_cor_l1b_20_c) and antenna-COG distance (cog_cor_01)
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'tracker_range_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 tracker_range_20_plrm_ku(time_20_c)
#      _FillValue: 2147483647
#      long_name: corrected tracker range for : 20 Hz PLRM Ku band
#      units: m
#      add_offset: 700000.0
#      scale_factor: 0.0001
#      coordinates: lon_20_c lat_20_c
#      comment: PLRM mode: tracker range corrected for USO frequency drift (uso_cor_20_c), internal path delay (int_path_cor_20_plrm_ku) , Doppler effect (dop_cor_l1b_20_plrm_ku) and antenna-COG distance (cog_cor_01)
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'h0_nav_dem_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  uint32 h0_nav_dem_20_ku(time_20_ku)
#      _FillValue: 4294967295
#      long_name: altitude command H0 computed with nav / DEM : 20 Hz Ku band
#      units: 3.125/64*10^-9s
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode : value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'agc_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 agc_20_ku(time_20_ku)
#      _FillValue: 32767
#      long_name: corrected AGC : 20 Hz Ku band
#      units: dB
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_ku lat_20_ku
#      comment: AGC corrected for instrumental errors (agc_cor_20_ku). For SAR mode, value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'agc_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 agc_20_c(time_20_c)
#      _FillValue: 32767
#      long_name: corrected AGC : 20 Hz C band
#      units: dB
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_c lat_20_c
#      comment: AGC corrected for instrumental errors (agc_cor_20_C). For SAR mode, value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'agc_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 agc_20_plrm_ku(time_20_c)
#      _FillValue: 32767
#      long_name: corrected AGC : 20 Hz Plrm Ku band
#      units: dB
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_c lat_20_c
#      comment: AGC corrected for instrumental errors (agc_cor_20_plrm_ku). For SAR mode, value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'agc_qual_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 agc_qual_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: quality flag for AGC : 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_ku lat_20_ku
#      comment: Flag indicating the use or not of the 20-Hz estimate of AGC in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'agc_qual_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 agc_qual_20_c(time_20_c)
#      _FillValue: 127
#      long_name: quality flag for AGC : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_c lat_20_c
#      comment: Flag indicating the use or not of the 20-Hz estimate of AGC in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'agc_qual_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 agc_qual_20_plrm_ku(time_20_c)
#      _FillValue: 127
#      long_name: quality flag for AGC : 20 Hz Plrm Ku band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_c lat_20_c
#      comment: Flag indicating the use or not of the 20-Hz estimate of AGC in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'scale_factor_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 scale_factor_20_ku(time_20_ku)
#      _FillValue: 2147483647
#      long_name: scaling factor for backscatter coefficient evaluation : 20 Hz Ku band
#      units: dB
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_ku lat_20_ku
#      comment: This scaling factor represents the backscatter coefficient for a waveform amplitude equal to 1. It is corrected for AGC instrumental errors (agc_cor_20_ku) and internal calibration (sig0_cal_20_ku)
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'scale_factor_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int32 scale_factor_20_c(time_20_c)
#      _FillValue: 2147483647
#      long_name: scaling factor for backscatter coefficient evaluation : 20 Hz C band
#      units: dB
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_c lat_20_c
#      comment: This scaling factor represents the backscatter coefficient for a waveform amplitude equal to 1. It is corrected for AGC instrumental errors (agc_cor_20_c) and internal calibration (sig0_cal_20_c)
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'scale_factor_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 scale_factor_20_plrm_ku(time_20_c)
#      _FillValue: 2147483647
#      long_name: scaling factor for backscatter coefficient evaluation : 20 Hz Plrm Ku band
#      units: dB
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_c lat_20_c
#      comment: This scaling factor represents the backscatter coefficient for a waveform amplitude equal to 1. It is corrected for AGC instrumental errors (agc_cor_20_plrm_ku) and internal calibration (sig0_cal_20_plrm_ku)
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'range_water_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 range_water_20_ku(time_20_ku)
#      _FillValue: 2147483647
#      long_name: corrected altimeter range from SAMOSA ocean retracker: 20 Hz Ku band
#      units: m
#      quality_flag: range_water_qual_20_ku
#      add_offset: 700000.0
#      scale_factor: 0.0001
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode:  SAMOSA retracker (Dinardo et al., 2015, DOI: 10.1109/IGARSS.2015.7327036). Instrumental corrections included : USO drift correction (uso_cor_20_ku), internal path correction (int_path_cor_20_ku), distance antenna-COG (cog_cor_01), Doppler correction (dop_cor_20_ku), modeled instrumental errors correction (mod_instr_cor_range_01_ku) and system bias (for measurements acquired in LRM during early commissioning phase, the MLE4 Brown retracker is used, Amarouche et al., 2004, DOI:  10.1080/01490410490465210)
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'range_water_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int32 range_water_20_c(time_20_c)
#      _FillValue: 2147483647
#      long_name: corrected altimeter range from MLE4 Brown retracker: 20 Hz C band
#      units: m
#      quality_flag: range_water_qual_20_c
#      add_offset: 700000.0
#      scale_factor: 0.0001
#      coordinates: lon_20_c lat_20_c
#      comment: LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Instrumental corrections included : USO drift correction (uso_cor_20_c), internal path correction (int_path_cor_20_c), distance antenna-COG (cog_cor_01), Doppler correction (dop_cor_20_c), modeled instrumental errors correction (mod_instr_cor_range_01_c) and system bias
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'range_water_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 range_water_20_plrm_ku(time_20_c)
#      _FillValue: 2147483647
#      long_name: corrected altimeter range from MLE4 Brown retracker: 20 Hz Plrm Ku band
#      units: m
#      quality_flag: range_water_qual_20_plrm_ku
#      add_offset: 700000.0
#      scale_factor: 0.0001
#      coordinates: lon_20_c lat_20_c
#      comment: Pseudo-LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Instrumental corrections included : USO drift correction (uso_cor_20_c), internal path correction (int_path_cor_20_plrm_ku), distance antenna-COG (cog_cor_01), Doppler correction (dop_cor_20_plrm_ku), modeled instrumental errors correction (mod_instr_cor_range_01_plrm_ku) and system bias
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'range_water_qual_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 range_water_qual_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: quality flag for the altimeter range derived from SAMOSA ocean retracker: 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: SAMOSA retracker (Dinardo et al., 2015, DOI: 10.1109/IGARSS.2015.7327036). Flag indicating the use or not of the 20-Hz estimate of the ocean altimeter range in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'range_water_qual_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 range_water_qual_20_c(time_20_c)
#      _FillValue: 127
#      long_name: quality flag for the 'ocean' altimeter range : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_c lat_20_c
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Flag indicating the use or not of the 20-Hz estimate of the ocean altimeter range in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'range_water_qual_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 range_water_qual_20_plrm_ku(time_20_c)
#      _FillValue: 127
#      long_name: quality flag for the altimeter range derived from the  MLE4 Brown retracker: 20 Hz Plrm Ku band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_c lat_20_c
#      comment: Pseudo-LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Flag indicating the use or not of the 20-Hz estimate of the ocean altimeter range in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'range_water_rms_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 range_water_rms_01_ku(time_01)
#      _FillValue: 32767
#      long_name: RMS of the 'ocean' altimeter range : 1 Hz Ku band
#      units: m
#      add_offset: 0.0
#      scale_factor: 0.0001
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Compression of high rate elements is preceded by a detection of outliers. Only valid high-rate values are used to compute this element
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'range_water_rms_01_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 range_water_rms_01_c(time_01)
#      _FillValue: 32767
#      long_name: RMS of the 'ocean' altimeter range : 1 Hz C band
#      units: m
#      add_offset: 0.0
#      scale_factor: 0.0001
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Compression of high rate elements is preceded by a detection of outliers. Only valid high-rate values are used to compute this element
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'range_water_rms_01_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 range_water_rms_01_plrm_ku(time_01)
#      _FillValue: 32767
#      long_name: RMS of the 'ocean' altimeter range : 1 Hz Plrm Ku band
#      units: m
#      add_offset: 0.0
#      scale_factor: 0.0001
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Compression of high rate elements is preceded by a detection of outliers. Only valid high-rate values are used to compute this element
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'range_water_numval_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 range_water_numval_01_ku(time_01)
#      _FillValue: 127
#      long_name: number of valid points used to compute the 'ocean' altimeter range : 1 Hz Ku band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'range_water_numval_01_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 range_water_numval_01_c(time_01)
#      _FillValue: 127
#      long_name: number of valid points used to compute the 'ocean' altimeter range : 1 Hz C band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'range_water_numval_01_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 range_water_numval_01_plrm_ku(time_01)
#      _FillValue: 127
#      long_name: number of valid points used to compute the 'ocean' altimeter range : 1 Hz Plrm Ku band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'interpolated_c_band_range_water_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 interpolated_c_band_range_water_20_ku(time_20_ku)
#      _FillValue: 2147483647
#      long_name: C-band interpolated corrected 'ocean' altimeter range : 20 Hz Ku band
#      units: m
#      quality_flag: range_water_qual_20_c
#      add_offset: 700000.0
#      scale_factor: 0.0001
#      coordinates: lon_20_ku lat_20_ku
#      comment: C-band altimeter range value used to compute the Ku-band altimeter ionospheric correction (iono_cor_alt_20_ku)
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'sig0_water_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 sig0_water_01_ku(time_01)
#      _FillValue: 32767
#      long_name: corrected backscatter coefficient derived from SAMOSA ocean retracker: 1 Hz Ku band
#      units: dB
#      standard_name: surface_backwards_scattering_coefficient_of_radar_wave
#      quality_flag: sig0_water_qual_01_ku
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_01 lat_01
#      comment: SAR mode: SAMOSA retracker (Dinardo et al., 2015, DOI: 10.1109/IGARSS.2015.7327036). Instrumental corrections included : AGC instrumental errors correction, internal calibration correction, modeled instrumental errors correction, atmospheric attenuation correction and system bias.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_01_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 sig0_water_01_c(time_01)
#      _FillValue: 32767
#      long_name: corrected backscatter coefficient derived from MLE4 Brown retracker: 1 Hz C band
#      units: dB
#      standard_name: surface_backwards_scattering_coefficient_of_radar_wave
#      quality_flag: sig0_water_qual_01_c
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_01 lat_01
#      comment: LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Instrumental corrections included : AGC instrumental errors correction, internal calibration correction, modeled instrumental errors correction, atmospheric attenuation correction and system bias.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_01_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 sig0_water_01_plrm_ku(time_01)
#      _FillValue: 32767
#      long_name: corrected backscatter coefficient derived from MLE4 Brown retracker: 1 Hz Plrm Ku band
#      units: dB
#      standard_name: surface_backwards_scattering_coefficient_of_radar_wave
#      quality_flag: sig0_water_qual_01_plrm_ku
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_01 lat_01
#      comment: Pseudo-LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Instrumental corrections included : AGC instrumental errors correction, internal calibration correction, modeled instrumental errors correction, atmospheric attenuation correction and system bias.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 sig0_water_20_ku(time_20_ku)
#      _FillValue: 32767
#      long_name: corrected backscatter coefficient from SAMOSA ocean retracker: 20 Hz Ku band
#      units: dB
#      standard_name: surface_backwards_scattering_coefficient_of_radar_wave
#      quality_flag: sig0_water_qual_20_ku
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: SAMOSA retracker (Dinardo et al., 2015, DOI: 10.1109/IGARSS.2015.7327036). Instrumental corrections included : AGC instrumental errors correction (agc_cor_20_ku), internal calibration correction (sig0_cal_20_ku), modeled instrumental errors correction (mod_instr_cor_sig0_01_ku), atmospheric attenuation correction (atm_cor_sig0_01_ku) and system bias (for measurements acquired in LRM during early commissioning phase, the MLE4 Brown retracker is used, Amarouche et al., 2004, DOI:  10.1080/01490410490465210)
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'sig0_water_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 sig0_water_20_c(time_20_c)
#      _FillValue: 32767
#      long_name: corrected backscatter coefficient from MLE4 Brown retracker: 20 Hz C band
#      units: dB
#      standard_name: surface_backwards_scattering_coefficient_of_radar_wave
#      quality_flag: sig0_water_qual_20_c
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_c lat_20_c
#      comment: LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Instrumental corrections included : AGC instrumental errors correction (agc_cor_20_c), internal calibration correction (sig0_cal_20_c), modeled instrumental errors correction (mod_instr_cor_sig0_01_c), atmospheric attenuation correction (atm_cor_sig0_01_c) and system bias.
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'sig0_water_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 sig0_water_20_plrm_ku(time_20_c)
#      _FillValue: 32767
#      long_name: corrected backscatter coefficient from MLE4 Brown retracker: 20 Hz Plrm Ku band
#      units: dB
#      standard_name: surface_backwards_scattering_coefficient_of_radar_wave
#      quality_flag: sig0_water_qual_20_plrm_ku
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_20_c lat_20_c
#      comment: Pseudo-LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Instrumental corrections included : AGC instrumental errors correction (agc_cor_20_plrm_ku), internal calibration correction (sig0_cal_20_plrm_ku), modeled instrumental errors correction (mod_instr_cor_sig0_01_plrm_ku), atmospheric attenuation correction (atm_cor_sig0_01_plrm_ku) and system bias
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'sig0_water_qual_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 sig0_water_qual_01_ku(time_01)
#      _FillValue: 127
#      long_name: quality flag for the backscatter coefficient from SAMOSA ocean/coastal retracker: 1 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: Good Bad
#      coordinates: lon_01 lat_01
#      comment: SAR mode: SAMOSA retracker (Dinardo et al., 2015, DOI: 10.1109/IGARSS.2015.7327036). Flag indicating the use or not of the 20-Hz estimate of the 'ocean' backscatter coefficient in the computation of 1Hz estimate (for measurements acquired in LRM during early commissioning phase, the MLE4 Brown retracker is used, Amarouche et al., 2004, DOI:  10.1080/01490410490465210)
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_qual_01_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 sig0_water_qual_01_c(time_01)
#      _FillValue: 127
#      long_name: quality flag for the backscatter coefficient from MLE4 Brown retracker: 1 Hz C band
#      flag_values: [0 1]
#      flag_meanings: Good Bad
#      coordinates: lon_01 lat_01
#      comment: LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Flag indicating the use or not of the 20-Hz estimate of the 'ocean' backscatter coefficient in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_qual_01_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 sig0_water_qual_01_plrm_ku(time_01)
#      _FillValue: 127
#      long_name: quality flag for the backscatter coefficient from MLE4 Brown retracker: 1 Hz Plrm Ku band
#      flag_values: [0 1]
#      flag_meanings: Good Bad
#      coordinates: lon_01 lat_01
#      comment: Pseudo-LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Flag indicating the use or not of the 20-Hz estimate of the 'ocean' backscatter coefficient in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_qual_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 sig0_water_qual_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: quality flag for the backscatter coefficient from SAMOSA ocean/coastal retracker: 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: SAMOSA retracker (Dinardo et al., 2015, DOI: 10.1109/IGARSS.2015.7327036). Flag indicating the use or not of the 20-Hz estimate of the 'ocean' backscatter coefficient in the computation of 1Hz estimate (for measurements acquired in LRM during early commissioning phase, the MLE4 Brown retracker is used, Amarouche et al., 2004, DOI:  10.1080/01490410490465210)
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'sig0_water_qual_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 sig0_water_qual_20_c(time_20_c)
#      _FillValue: 127
#      long_name: quality flag for the backscatter coefficient from MLE4 Brown retracker: 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_c lat_20_c
#      comment: LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Flag indicating the use or not of the 20-Hz estimate of the 'ocean' backscatter coefficient in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'sig0_water_qual_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 sig0_water_qual_20_plrm_ku(time_20_c)
#      _FillValue: 127
#      long_name: quality flag for the backscatter coefficient from MLE4 Brown retracker: 20 Hz Plrm Ku band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_c lat_20_c
#      comment: Pseudo-LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Flag indicating the use or not of the 20-Hz estimate of the 'ocean' backscatter coefficient in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'sig0_water_rms_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 sig0_water_rms_01_ku(time_01)
#      _FillValue: 32767
#      long_name: RMS of the 'ocean' backscatter coefficient: 1 Hz Ku band
#      units: dB
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Compression of high rate elements is preceded by a detection of outliers. Only valid high-rate values are used to compute this element
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_rms_01_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 sig0_water_rms_01_c(time_01)
#      _FillValue: 32767
#      long_name: RMS of the 'ocean' backscatter coefficient: 1 Hz C band
#      units: dB
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Compression of high rate elements is preceded by a detection of outliers. Only valid high-rate values are used to compute this element
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_rms_01_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 sig0_water_rms_01_plrm_ku(time_01)
#      _FillValue: 32767
#      long_name: RMS of the 'ocean' backscatter coefficient: 1 Hz Plrm Ku band
#      units: dB
#      add_offset: 0.0
#      scale_factor: 0.01
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Compression of high rate elements is preceded by a detection of outliers. Only valid high-rate values are used to compute this element
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_numval_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 sig0_water_numval_01_ku(time_01)
#      _FillValue: 127
#      long_name: number of valid points used to compute the 'ocean' backscatter coefficient: 1 Hz Ku band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_numval_01_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 sig0_water_numval_01_c(time_01)
#      _FillValue: 127
#      long_name: number of valid points used to compute the 'ocean' backscatter coefficient: 1 Hz C band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'sig0_water_numval_01_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 sig0_water_numval_01_plrm_ku(time_01)
#      _FillValue: 127
#      long_name: number of valid points used to compute the 'ocean' backscatter coefficient: 1 Hz Plrm Ku band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'swh_water_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 swh_water_20_ku(time_20_ku)
#      _FillValue: 32767
#      long_name: corrected significant waveheight derived from SAMOSA ocean retracker: 20 Hz Ku band
#      units: m
#      standard_name: sea_surface_wave_significant_height
#      quality_flag: swh_water_qual_20_ku
#      add_offset: 0.0
#      scale_factor: 0.001
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: SAMOSA retracker (Dinardo et al., 2015, DOI: 10.1109/IGARSS.2015.7327036). Instrumental corrections included : modeled instrumental errors correction (mod_instr_cor_swh_01_ku) and system bias.
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'swh_water_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 swh_water_20_c(time_20_c)
#      _FillValue: 32767
#      long_name: corrected 'ocean' significant waveheight : 20 Hz C band
#      units: m
#      standard_name: sea_surface_wave_significant_height
#      quality_flag: swh_water_qual_20_c
#      add_offset: 0.0
#      scale_factor: 0.001
#      coordinates: lon_20_c lat_20_c
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Instrumental corrections included : modeled instrumental errors correction (mod_instr_cor_swh_01_c) and system bias.
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'swh_water_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 swh_water_20_plrm_ku(time_20_c)
#      _FillValue: 32767
#      long_name: corrected significant waveheight derived from MLE4 Brown retracker: 20 Hz Plrm Ku band
#      units: m
#      standard_name: sea_surface_wave_significant_height
#      quality_flag: swh_water_qual_20_plrm_ku
#      add_offset: 0.0
#      scale_factor: 0.001
#      coordinates: lon_20_c lat_20_c
#      comment: Pseudo-LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Instrumental corrections included : modeled instrumental errors correction (mod_instr_cor_swh_01_plrm_ku) and system bias.
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'swh_water_qual_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 swh_water_qual_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: quality flag for the significant waveheight from SAMOSA ocean retracker: 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: SAMOSA retracker (Dinardo et al., 2015, DOI: 10.1109/IGARSS.2015.7327036). Flag indicating the use or not of the 20-Hz estimate of the 'ocean' significant waveheight in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'swh_water_qual_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 swh_water_qual_20_c(time_20_c)
#      _FillValue: 127
#      long_name: quality flag for the 'ocean' significant waveheight: 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_c lat_20_c
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Flag indicating the use or not of the 20-Hz estimate of the 'ocean' significant waveheight in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'swh_water_qual_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 swh_water_qual_20_plrm_ku(time_20_c)
#      _FillValue: 127
#      long_name: quality flag for the significant waveheight from MLE4 Brown retracker: 20 Hz Plrm Ku band
#      flag_values: [0 1]
#      flag_meanings: Yes No
#      coordinates: lon_20_c lat_20_c
#      comment: Pseudo-LRM only: MLE4 Brown retracker from Amarouche et al. (2004), DOI:  10.1080/01490410490465210. Flag indicating the use or not of the 20-Hz estimate of the 'ocean' significant waveheight in the computation of 1Hz estimate
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'swh_water_rms_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 swh_water_rms_01_ku(time_01)
#      _FillValue: 32767
#      long_name: RMS of the 'ocean' significant waveheight: 1 Hz Ku band
#      units: m
#      add_offset: 0.0
#      scale_factor: 0.001
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Compression of high rate elements is preceded by a detection of outliers. Only valid high-rate values are used to compute this element
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'swh_water_rms_01_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 swh_water_rms_01_c(time_01)
#      _FillValue: 32767
#      long_name: RMS of the 'ocean' significant waveheight: 1 Hz C band
#      units: m
#      add_offset: 0.0
#      scale_factor: 0.001
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Compression of high rate elements is preceded by a detection of outliers. Only valid high-rate values are used to compute this element
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'swh_water_rms_01_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 swh_water_rms_01_plrm_ku(time_01)
#      _FillValue: 32767
#      long_name: RMS of the 'ocean' significant waveheight: 1 Hz Plrm Ku band
#      units: m
#      add_offset: 0.0
#      scale_factor: 0.001
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking. Compression of high rate elements is preceded by a detection of outliers. Only valid high-rate values are used to compute this element
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'swh_water_numval_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 swh_water_numval_01_ku(time_01)
#      _FillValue: 127
#      long_name: number of valid points used to compute the 'ocean' significant waveheight: 1 Hz Ku band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'swh_water_numval_01_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 swh_water_numval_01_c(time_01)
#      _FillValue: 127
#      long_name: number of valid points used to compute the 'ocean' significant waveheight: 1 Hz C band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'swh_water_numval_01_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 swh_water_numval_01_plrm_ku(time_01)
#      _FillValue: 127
#      long_name: number of valid points used to compute the 'ocean' significant waveheight: 1 Hz Plrm Ku band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'epoch_water_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 epoch_water_20_ku(time_20_ku)
#      _FillValue: 2147483647
#      long_name: Epoch / ocean retracking : 20 Hz Ku band
#      units: s
#      add_offset: 0.0
#      scale_factor: 1e-15
#      coordinates: lon_20_ku lat_20_ku
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking.
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'epoch_water_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int32 epoch_water_20_c(time_20_c)
#      _FillValue: 2147483647
#      long_name: Epoch / ocean retracking : 20 Hz C band
#      units: s
#      add_offset: 0.0
#      scale_factor: 1e-15
#      coordinates: lon_20_c lat_20_c
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking.
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'epoch_water_20_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 epoch_water_20_plrm_ku(time_20_c)
#      _FillValue: 2147483647
#      long_name: Epoch / ocean retracking : 20 Hz Plrm Ku band
#      units: s
#      add_offset: 0.0
#      scale_factor: 1e-15
#      coordinates: lon_20_c lat_20_c
#      comment: LRM mode : ocean retracking, SAR mode : ocean/coastal retracking.
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'sigmac_water_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 sigmac_water_20_ku(time_20_ku)
#      _FillValue: 2147483647
#      long_name: Composite Sigma / 'ocean' retracking : 20 Hz Ku band
#      units: s
#      add_offset: 0.0
#      scale_factor: 1e-15
#      coordinates: lon_20_ku lat_20_ku
#      comment: LRM mode : ocean retracking, SAR mode : N.A.
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'sigmac_water_20_c': <class 'netCDF4._netCDF4.Variable'>
# ...
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'nav_bul_coarse_time_20_c': <class 'netCDF4._netCDF4.Variable'>
#  uint32 nav_bul_coarse_time_20_c(time_20_c)
#      _FillValue: 4294967295
#      long_name: navigation bulletin coarse time : 20 Hz C band
#      units: second
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'nav_bul_fine_time_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  uint32 nav_bul_fine_time_20_ku(time_20_ku)
#      _FillValue: 4294967295
#      long_name: navigation bulletin fine time : 20 Hz Ku band
#      units: 2^-24 second
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'nav_bul_fine_time_20_c': <class 'netCDF4._netCDF4.Variable'>
#  uint32 nav_bul_fine_time_20_c(time_20_c)
#      _FillValue: 4294967295
#      long_name: navigation bulletin fine time : 20 Hz C band
#      units: 2^-24 second
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'seq_count_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  uint16 seq_count_20_ku(time_20_ku)
#      _FillValue: 65535
#      long_name: sequence count : 20 Hz Ku band
#      units: count
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'seq_count_20_c': <class 'netCDF4._netCDF4.Variable'>
#  uint16 seq_count_20_c(time_20_c)
#      _FillValue: 65535
#      long_name: sequence count : 20 Hz C band
#      units: count
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'isp_time_status_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 isp_time_status_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: ISP time status : 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: SRAL_OBT_extrapolated SRAL_OBT_updated_with_SMU_OBT
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'isp_time_status_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 isp_time_status_20_c(time_20_c)
#      _FillValue: 127
#      long_name: ISP time status : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: SRAL_OBT_extrapolated SRAL_OBT_updated_with_SMU_OBT
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'oper_instr_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 oper_instr_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: operating instrument : 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: A B
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement - Instrument A stands for SRAL Nominal and instrument B stands for SRAL Redundant
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'oper_instr_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 oper_instr_20_c(time_20_c)
#      _FillValue: 127
#      long_name: operating instrument : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: A B
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement - Instrument A stands for SRAL Nominal and instrument B stands for SRAL Redundant
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'cl_gain_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 cl_gain_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: tracking configuration - closed loop gain : 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: Nominal_value Nominal_value_with_back_off
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'cl_gain_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 cl_gain_20_c(time_20_c)
#      _FillValue: 127
#      long_name: tracking configuration - closed loop gain : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: Nominal_value Nominal_value_with_back_off
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'acq_stat_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 acq_stat_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: tracking configuration - acquisition status : 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: no_acquisition acquisition
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'acq_stat_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 acq_stat_20_c(time_20_c)
#      _FillValue: 127
#      long_name: tracking configuration - acquisition status : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: no_acquisition acquisition
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'dem_eeprom_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 dem_eeprom_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: tracking configuration - DEM EEPROM read access : 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: enabled disabled
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'dem_eeprom_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 dem_eeprom_20_c(time_20_c)
#      _FillValue: 127
#      long_name: tracking configuration - DEM EEPROM read access : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: enabled disabled
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'weighting_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 weighting_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: altimeter configuration - weighting function : 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: enabled disabled
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'weighting_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 weighting_20_c(time_20_c)
#      _FillValue: 127
#      long_name: altimeter configuration - weighting function : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: enabled disabled
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'loss_track_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 loss_track_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: loss of track criterion: 20 Hz Ku band
#      flag_values: [0 1]
#      flag_meanings: normal loss_of_track
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'loss_track_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 loss_track_20_c(time_20_c)
#      _FillValue: 127
#      long_name: loss of track criterion: 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: normal loss_of_track
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'flag_man_pres_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 flag_man_pres_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: manoeuvre presence flag : 20 Hz ku band
#      flag_values: [0 1]
#      flag_meanings: no_manoeuvre ongoing_manoeuvre
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'flag_man_pres_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 flag_man_pres_20_c(time_20_c)
#      _FillValue: 127
#      long_name: manoeuvre presence flag : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: no_manoeuvre ongoing_manoeuvre
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'flag_man_thrust_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 flag_man_thrust_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: manoeuvre thrust flag : 20 Hz ku band
#      flag_values: [0 1]
#      flag_meanings: no_thrust ongoing_thrust
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'flag_man_thrust_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 flag_man_thrust_20_c(time_20_c)
#      _FillValue: 127
#      long_name: manoeuvre thrust flag : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: no_thrust ongoing_thrust
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'flag_man_plane_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 flag_man_plane_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: manoeuvre plane flag : 20 Hz ku band
#      flag_values: [0 1]
#      flag_meanings: in_plane out_of_plane
#      coordinates: lon_20_ku lat_20_ku
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'flag_man_plane_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int8 flag_man_plane_20_c(time_20_c)
#      _FillValue: 127
#      long_name: manoeuvre plane flag : 20 Hz C band
#      flag_values: [0 1]
#      flag_meanings: in_plane out_of_plane
#      coordinates: lon_20_c lat_20_c
#      comment: SAR mode: value the closest in time to the reference measurement
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'index_1hz_meas_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 index_1hz_meas_20_ku(time_20_ku)
#      _FillValue: 32767
#      long_name: Index of the 1Hz measurement : 20 Hz ku band
#      units: count
#      coordinates: lon_20_ku lat_20_ku
#      comment: Index of the 1-Hz measurement associated to the 20-Hz measurement, zero index corresponding to the first 1-Hz measurement of the dataset.
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'index_1hz_meas_20_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 index_1hz_meas_20_c(time_20_c)
#      _FillValue: 32767
#      long_name: Index of the 1Hz measurement : 20 Hz C band
#      units: count
#      coordinates: lon_20_c lat_20_c
#      comment: Index of the 1-Hz measurement associated to the 20-Hz measurement, zero index corresponding to the first 1-Hz measurement of the dataset.
#  unlimited dimensions:
#  current shape = (12780,)
#  filling on,
#  'index_first_20hz_meas_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int32 index_first_20hz_meas_01_ku(time_01)
#      _FillValue: 2147483647
#      long_name: Index of the first 20Hz measurement : 01 Hz ku band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: Index of the first 20-Hz measurement associated to the 1-Hz measurement, zero index corresponding to the first 20-Hz measurement of the dataset.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'index_first_20hz_meas_01_c': <class 'netCDF4._netCDF4.Variable'>
#  int32 index_first_20hz_meas_01_c(time_01)
#      _FillValue: 2147483647
#      long_name: Index of the first 20Hz measurement : 01 Hz C band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: Index of the first 20-Hz measurement associated to the 1-Hz measurement, zero index corresponding to the first 20-Hz measurement of the dataset.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'num_20hz_meas_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 num_20hz_meas_01_ku(time_01)
#      _FillValue: 32767
#      long_name: Number of 20Hz measurements : 01 Hz ku band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: Number of 20-Hz measurements associated to the 1-Hz measurement.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'num_20hz_meas_01_c': <class 'netCDF4._netCDF4.Variable'>
#  int16 num_20hz_meas_01_c(time_01)
#      _FillValue: 32767
#      long_name: Number of 20Hz measurements : 01 Hz C band
#      units: count
#      coordinates: lon_01 lat_01
#      comment: Number of 20-Hz measurements associated to the 1-Hz measurement.
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'orbit_type_01': <class 'netCDF4._netCDF4.Variable'>
#  int8 orbit_type_01(time_01)
#      _FillValue: 127
#      long_name: Orbit type flag : 1 Hz Ku band
#      flag_values: [0 1 2 3 4 5 6 7 8]
#      flag_meanings: osf fos navatt doris_nav gnss_roe pod_moe salp_moe pod_poe salp_poe
#      coordinates: lon_01 lat_01
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'waveform_qual_ice_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  int8 waveform_qual_ice_20_ku(time_20_ku)
#      _FillValue: 127
#      long_name: Ice waveform quality check status : 20 Hz ku band
#      flag_mask: [ 0  1  2  4  8 16 32]
#      flag_meanings: waveform_ok total_power_test_failed noise_power_test_failed variance_test_failed leading_edge_test_failed low_peakiness_test_failed high_peakiness_test_failed
#      coordinates: lon_20_ku lat_20_ku
#  unlimited dimensions:
#  current shape = (13101,)
#  filling on,
#  'iono_cor_alt_filtered_01_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 iono_cor_alt_filtered_01_ku(time_01)
#      _FillValue: 32767
#      long_name: altimeter ionospheric range filtered: 1 Hz Ku Band
#      units: m
#      standard_name: altimeter_range_correction_due_to_ionosphere
#      add_offset: 0.0
#      scale_factor: 0.0001
#      coordinates: lon_01 lat_01
#      comment: An ionospheric correction must be added (negative value) to the instrument range to correct this range measurement for ionospheric range delays of the radar pulse. This correction is valid over ocean surfaces only
#      source: SRAL
#      institution: TAS
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'iono_cor_alt_filtered_01_plrm_ku': <class 'netCDF4._netCDF4.Variable'>
#  int16 iono_cor_alt_filtered_01_plrm_ku(time_01)
#      _FillValue: 32767
#      long_name: altimeter ionospheric range filtered: 1 Hz Plrm Ku Band
#      units: m
#      standard_name: altimeter_range_correction_due_to_ionosphere
#      add_offset: 0.0
#      scale_factor: 0.0001
#      coordinates: lon_01 lat_01
#      comment: An ionospheric correction must be added (negative value) to the instrument range to correct this range measurement for ionospheric range delays of the radar pulse. This correction is valid over ocean surfaces only
#      source: SRAL
#      institution: TAS
#  unlimited dimensions:
#  current shape = (661,)
#  filling on,
#  'rip_20_ku': <class 'netCDF4._netCDF4.Variable'>
#  uint32 rip_20_ku(time_20_ku, max_multi_stack_ind)
#      long_name: RIP, Range Integrated Power: l1b_echo_sar_ku mode
#      comment: the useful values of the table are the first nb_stack_l1b_echo_sar_ku values, one value of power for each individual echoe
#      units: FFT power unit
#      _FillValue: 4294967295
#      coordinates: lon_20_ku lat_20_ku
#  unlimited dimensions:
#  current shape = (13101, 256)
#  filling on}

# %%
data_normalized.shape
# Out:
# (13101, 3)

# %% [markdown]
# There are some NaN values in the dataset so one way to deal with this is to delete them.

# %%
nan_count = np.isnan(data_normalized).sum()
print(f"Number of NaN values in the array: {nan_count}")
data_cleaned = data_normalized[~np.isnan(data_normalized).any(axis=1)]
# Out:
# Number of NaN values in the array: 387

# %%
data_cleaned.shape
# Out:
# (12815, 3)

# %% [markdown]
# Now, let's proceed with running the GMM model as usual. Remember, you have the flexibility to substitute this with K-Means or any other preferred model.

# %%
gmm = GaussianMixture(n_components=2, random_state=0)
gmm.fit(data_cleaned)
clusters_gmm = gmm.predict(data_cleaned)

# %% [markdown]
# We can also inspect how many data points are there in each class of your clustering prediction.

# %%
unique, counts = np.unique(clusters_gmm, return_counts=True)
class_counts = dict(zip(unique, counts))

print(class_counts)
# Out:
# {0: 8670, 1: 4145}
